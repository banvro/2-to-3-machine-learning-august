# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples = 100, n_features = 2, n_informative = 2, n_targets = 1, noise = 50)

# %%
df = pd.DataFrame({"fetur1" : x[:, 0], "feature2" : x[:, 1], "target" : y})

# %%
df
# Out:
#       fetur1  feature2      target
# 0   1.502025  0.523335  166.869747
# 1  -0.465347 -1.194500 -170.046339
# 2  -0.875392  0.873464   25.015268
# 3  -0.723516  2.591052  157.480089
# 4   0.901114 -0.208176  123.038977
# ..       ...       ...         ...
# 95  1.610196 -0.533666   61.681616
# 96  1.009500  0.650128  195.106785
# 97  2.988808  0.537742  288.675187
# 98 -0.891031 -0.588308 -108.917119
# 99  0.304936 -1.215068 -127.677764
#
# [100 rows x 3 columns]

# %%
# import matplotlib.pyplot as pli

import plotly.express as px

# %%
import plotly.offline as pyo 
pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
px.scatter_3d(df, x = "fetur1", y = "feature2", z = "target")
# Out:
# <div>                            <div id="0525e9d0-6f09-4bfa-94a5-3bb49fd4bf00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0525e9d0-6f09-4bfa-94a5-3bb49fd4bf00")) {                    Plotly.newPlot(                        "0525e9d0-6f09-4bfa-94a5-3bb49fd4bf00",                        [{"hovertemplate":"fetur1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[1.5020249602086566,-0.4653470991251232,-0.8753924363000063,-0.7235160115411257,0.9011144079087247,-0.33942891806764086,-0.5801880244626006,-0.03306360650018563,0.05241620892540618,-0.8309418936493146,-0.1276321775
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
obj = LinearRegression()

# %%
obj.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = obj.predict(x_test)

# %%
y_pred
# Out:
# array([ -67.32550688,   19.35767034,   87.76461263,   21.89068828,
#          53.43982051,  151.54064902,    2.79651564,  135.1720673 ,
#         -31.54845124,   60.66925132,   76.29059082,  185.66150087,
#        -144.09078992,   11.63119468,  188.49182159,   -7.79224915,
#          15.1815671 ,   37.85547902,   -3.73422976,   50.19503007])

# %%
obj.coef_
# Out:
# array([83.51371206, 82.8709819 ])

# %%
obj.intercept_
# Out:
# -3.0117755909754145

# %%
y = -3.0117755909754145 + 83.51371206 * 1.50202496 + 82.8709819 *  0.52333526

y
# Out:
# 165.79721128448938

# %%
y
# Out:
# 165.79721128448938

# %%
import plotly.graph_objects as go


import numpy as np

x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(y, x)
final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

z_final = obj.predict(final).reshape(10,10)

z = z_final
# "fetur1", y = "feature2"

fig = px.scatter_3d(df, x='fetur1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# <div>                            <div id="88627e98-8c22-4a68-8831-d0a1d7117034" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88627e98-8c22-4a68-8831-d0a1d7117034")) {                    Plotly.newPlot(                        "88627e98-8c22-4a68-8831-d0a1d7117034",                        [{"hovertemplate":"fetur1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[1.5020249602086566,-0.4653470991251232,-0.8753924363000063,-0.7235160115411257,0.9011144079087247,-0.33942891806764086,-0.5801880244626006,-0.03306360650018563,0.05241620892540618,-0.8309418936493146,-0.1276321775
# ...

# %%
import numpy as np

# %%
# Polynomial regresssion

# %%
x = 6 * np.random.rand(200, 1) - 3
y = 0.8 * X**2 + 0.9 * X + 2 + np.random.randn(200, 1)

# y = 0.8x^2 + 0.9x + 2

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y, "b.")

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
obj = LinearRegression()

# %%
obj.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = obj.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.018028821365490666

# %%
plt.plot(x_train, y_train, "b.")
plt.plot(x_test, y_test, "r.")
plt.plot(x_train, obj.predict(x_train), color="r")

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
ploy = PolynomialFeatures(degree=3)

# %%
x_train_new = ploy.fit_transform(x_train)

# %%
x_train_new
# Out:
# array([[ 1.00000000e+00, -2.84410684e+00,  8.08894373e+00,
#         -2.30058202e+01],
#        [ 1.00000000e+00,  1.06805771e+00,  1.14074728e+00,
#          1.21838393e+00],
#        [ 1.00000000e+00, -6.27740725e-02,  3.94058417e-03,
#         -2.47366516e-04],
#        [ 1.00000000e+00,  2.81226700e+00,  7.90884565e+00,
#          2.22417856e+01],
#        [ 1.00000000e+00, -2.31211081e+00,  5.34585641e+00,
#         -1.23602124e+01],
#        [ 1.00000000e+00, -3.73384291e-01,  1.39415829e-01,
#         -5.20556806e-02],
#        [ 1.00000000e+00, -1.66350627e+00,  2.76725310e+00,
#         -4.60334286e+00],
#        [ 1.00000000e+00,  1.47007641e-01,  2.16112465e-02,
#          3.17701836e-03],
#        [ 1.00000000e+00,  2.21352921e+00,  4.89971156e+00,
#          1.08456546e+01],
#        [ 1.00000000e+00, -8.38290904e-02,  7.02731639e-03,
#         -5.89093541e-04],
#        [ 1.00000000e+00, -2.28759990e+00,  5.23311329e+00,
#         -1.19712694e+01],
# ...

# %%
x_test_t = ploy.transform(x_test)

# %%
x_test_t
# Out:
# array([[ 1.00000000e+00,  2.74008363e+00,  7.50805830e+00,
#          2.05727076e+01],
#        [ 1.00000000e+00, -2.92513365e+00,  8.55640690e+00,
#         -2.50286338e+01],
#        [ 1.00000000e+00,  1.08574338e+00,  1.17883869e+00,
#          1.27991631e+00],
#        [ 1.00000000e+00,  2.90604147e+00,  8.44507701e+00,
#          2.45417440e+01],
#        [ 1.00000000e+00, -1.60695478e+00,  2.58230367e+00,
#         -4.14964522e+00],
#        [ 1.00000000e+00,  1.67104252e+00,  2.79238309e+00,
#          4.66619086e+00],
#        [ 1.00000000e+00, -8.65419423e-01,  7.48950778e-01,
#         -6.48156550e-01],
#        [ 1.00000000e+00, -2.35118993e+00,  5.52809411e+00,
#         -1.29975992e+01],
#        [ 1.00000000e+00,  1.11078618e+00,  1.23384594e+00,
#          1.37053903e+00],
#        [ 1.00000000e+00, -9.39879600e-01,  8.83373663e-01,
#         -8.30264886e-01],
#        [ 1.00000000e+00, -1.34551271e+00,  1.81040446e+00,
#         -2.43592222e+00],
# ...

# %%
lt = LinearRegression()

# %%
lt.fit(x_train_new, y_train)
# Out:
# LinearRegression()

# %%
y_preds = lt.predict(x_test_t)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_preds)
# Out:
# -0.054052382233777285
